# %%
#Used this to produce graphs and compare data using matplotlib

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("concrete_strength.csv")
plt.style.use('ggplot')

# create histograms
df.hist()

# create correlation graph with data distributions - df.plot.scatter(x=,y=)
# - replace x with the column you want to compare -
#df.plot.scatter(x = "plant_id", y = "compressive_strength_mpa")

plt.show() # Display the histogram plots
