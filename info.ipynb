# %%
#used this to get the summarised csv file info

import pandas as pd

df = pd.read_csv("concrete_strength.csv")

# output the first 5 rows of the table
#print(df.head())

# summarise the entire graph (this prints to console)
#print(df.describe())

# summarise data columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   batch_id                  5000 non-null   int64
#  1   plant_id                  5000 non-null   object
#  2   operator_shift            5000 non-null   object
#  3   day_of_week               5000 non-null   int64
#  4   cement_brand              4937 non-null   object
#  5   cement_kg_m3              5000 non-null   float64
#  6   slag_kg_m3                5000 non-null   float64
#  7   fly_ash_kg_m3             5000 non-null   float64
#  8   silica_fume_kg_m3         5000 non-null   float64
#  9   water_kg_m3               5000 non-null   float64
#  10  superplasticizer_kg_m3    4914 non-null   float64
#  11  fine_aggregate_kg_m3      5000 non-null   float64
#  12  coarse_aggregate_kg_m3    5000 non-null   float64
#  13  air_content_pct           4921 non-null   float64
#  14  slump_mm                  4783 non-null   float64
#  15  mix_time_s                5000 non-null   float64
#  16  temperature_C             5000 non-null   float64
#  17  humidity_pct              4845 non-null   float64
#  18  curing_method             4957 non-null   object
#  19  aggregate_type            5000 non-null   object
#  20  nearby_traffic_count      5000 non-null   int64
#  21  sensor_noise_index        5000 non-null   float64
#  22  age_days                  5000 non-null   int64
#  23  compressive_strength_mpa  5000 non-null   float64
# dtypes: float64(15), int64(4), object(5)
# memory usage: 937.6+ KB
